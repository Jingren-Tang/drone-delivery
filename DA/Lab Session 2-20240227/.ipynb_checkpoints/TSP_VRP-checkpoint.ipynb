# %%
import math
from itertools import combinations
import gurobipy as gp
from gurobipy import GRB, tupledict
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1: TSP
#
# The Traveling Salesman Problem (TSP) is a problem where a salesman wants to visit all cities only once and return to the origin city with the least distance traveled.

# %%
# List of coordinates of 10 cities

cities = [(17, 72), (97, 8), (32, 15), (63, 97), (57, 60), (83, 48), (100, 26), (12, 62), (3, 49), (55, 77)]
n=len(cities)

# %%
# Dictionary of Euclidean distance between each pair of points

dist = {(i, j): math.sqrt(sum((cities[i][k]-cities[j][k])**2 for k in range(2)))
        for i in range(n) for j in range(i)}

# %%
# Plots a TSP solution

def figure_TSP(sol):
    ax = plt.gca() #get cuttent axis
    ax.cla() # clear things for fresh plot

    # change default range
    ax.set_xlim((0, 105))
    ax.set_ylim((0, 105))
    a = []
    b = []
    
    for i in sol:
        a = np.append(a, cities[i][1])
        b = np.append(b, cities[i][0])
    
    a = np.append(a, cities[sol[0]][1])
    b = np.append(b, cities[sol[0]][0]) 
    ax.plot(a,b)
    
    for i in sol:
        ax.plot(cities[i][1], cities[i][0], 'o',color = 'r')
        ax.text(cities[i][1], cities[i][0], str(i), color='black', fontsize=12)
    plt.show()

# %%
ex_opt_tour = [3, 0, 7, 8, 2, 4, 1, 6, 5, 9]
figure_TSP(ex_opt_tour)

# %% [markdown]
# Part 1: Model the full MILP

# %% [markdown]
# ### 2 Index formulation of the TSP

# %% [markdown]
# \begin{align}
#     Minimize & \sum_{i,j\in E}c_{i,j}x_{i,j}\\
#     \textit{s.t.}&
#     \sum_{i,j \in A | i < j } x_{i,j}=2 & \forall i \in N,\\
#     &\sum_{i,j \in A | i,j \in S }x_{i,j} \leq |S|-1 & \forall S\subseteq N, 3 \leq |S|\\
#     &\nonumber x_{ij} \in \{0,1\} & \forall (i,j)\in A.
# \end{align}

# %% [markdown]
# Builds a tour from a solution with active edges

# %%
def build_tour_from_edges(edges):
    tour = []
    unvisited = list(range(n)) 
    start = 0
    neighbors = [j for i, j in edges.select(0, '*') if j in unvisited]
    while len(neighbors) >= 1:
        tour.append(neighbors[0])
        unvisited.remove(neighbors[0])
        neighbors = [j for i, j in edges.select(neighbors[0], '*') if j in unvisited]
    return tour

# %%
# Full model
m = gp.Model()

# Create variables
x = tupledict()
for i, j in dist.keys():
    x[i, j] = m.addVar(vtype=GRB.BINARY, name=f'x[{i},{j}]')
    x[j, i] = x[i, j]  # Edges both directions are the same 

# Add degree-2 constraints

m.addConstrs(x.sum(i, '*') == 2 for i in range(n))

# subtour constraints
count = 0
for tourlength in range(3, n):
    for subtour in combinations(range(n), tourlength):
        m.addConstr(gp.quicksum(x[i, j] for i, j in combinations(subtour, 2)) <= len(subtour)-1)
        count +=1
        print(subtour," constraints = ",count)

# set objective

objective = gp.quicksum(dist[i, j] * x[i, j] for i, j in dist.keys())
m.setObjective(objective, GRB.MINIMIZE)
m.setParam("OutputFlag", 1)

# Optimize model
m.optimize()

vals = m.getAttr('X', x)
edges = gp.tuplelist((i, j) for i, j in vals.keys() if vals[i, j] > 0.5)
tour = build_tour_from_edges(edges)

print('')
print(f'Optimal tour: {str(tour)}')
print(f'Optimal cost: {m.ObjVal}')
print('')

figure_TSP(tour)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-02-17
# (0, 1, 2)  constraints =  1
# (0, 1, 3)  constraints =  2
# (0, 1, 4)  constraints =  3
# (0, 1, 5)  constraints =  4
# (0, 1, 6)  constraints =  5
# (0, 1, 7)  constraints =  6
# (0, 1, 8)  constraints =  7
# (0, 1, 9)  constraints =  8
# (0, 2, 3)  constraints =  9
# (0, 2, 4)  constraints =  10
# (0, 2, 5)  constraints =  11
# (0, 2, 6)  constraints =  12
# (0, 2, 7)  constraints =  13
# (0, 2, 8)  constraints =  14
# (0, 2, 9)  constraints =  15
# (0, 3, 4)  constraints =  16
# (0, 3, 5)  constraints =  17
# (0, 3, 6)  constraints =  18
# (0, 3, 7)  constraints =  19
# (0, 3, 8)  constraints =  20
# (0, 3, 9)  constraints =  21
# (0, 4, 5)  constraints =  22
# (0, 4, 6)  constraints =  23
# (0, 4, 7)  constraints =  24
# (0, 4, 8)  constraints =  25
# (0, 4, 9)  constraints =  26
# (0, 5, 6)  constraints =  27
# (0, 5, 7)  constraints =  28
# (0, 5, 8)  constraints =  29
# (0, 5, 9)  constraints =  30
# (0, 6, 7)  constraints =  31
# (0, 6, 8)  constraints =  32
# (0, 6, 9)  constraints =  33
# (0, 7, 8)  constraints =  34
# (0, 7, 9)  constraints =  35
# (0, 8, 9)  constraints =  36
# (1, 2, 3)  constraints =  37
# (1, 2, 4)  constraints =  38
# (1, 2, 5)  constraints =  39
# (1, 2, 6)  constraints =  40
# (1, 2, 7)  constraints =  41
# (1, 2, 8)  constraints =  42
# (1, 2, 9)  constraints =  43
# (1, 3, 4)  constraints =  44
# (1, 3, 5)  constraints =  45
# (1, 3, 6)  constraints =  46
# (1, 3, 7)  constraints =  47
# (1, 3, 8)  constraints =  48
# (1, 3, 9)  constraints =  49
# (1, 4, 5)  constraints =  50
# (1, 4, 6)  constraints =  51
# (1, 4, 7)  constraints =  52
# (1, 4, 8)  constraints =  53
# (1, 4, 9)  constraints =  54
# (1, 5, 6)  constraints =  55
# (1, 5, 7)  constraints =  56
# (1, 5, 8)  constraints =  57
# (1, 5, 9)  constraints =  58
# (1, 6, 7)  constraints =  59
# (1, 6, 8)  constraints =  60
# (1, 6, 9)  constraints =  61
# (1, 7, 8)  constraints =  62
# (1, 7, 9)  constraints =  63
# (1, 8, 9)  constraints =  64
# (2, 3, 4)  constraints =  65
# (2, 3, 5)  constraints =  66
# (2, 3, 6)  constraints =  67
# (2, 3, 7)  constraints =  68
# (2, 3, 8)  constraints =  69
# (2, 3, 9)  constraints =  70
# (2, 4, 5)  constraints =  71
# (2, 4, 6)  constraints =  72
# (2, 4, 7)  constraints =  73
# (2, 4, 8)  constraints =  74
# (2, 4, 9)  constraints =  75
# (2, 5, 6)  constraints =  76
# (2, 5, 7)  constraints =  77
# (2, 5, 8)  constraints =  78
# (2, 5, 9)  constraints =  79
# (2, 6, 7)  constraints =  80
# (2, 6, 8)  constraints =  81
# (2, 6, 9)  constraints =  82
# (2, 7, 8)  constraints =  83
# (2, 7, 9)  constraints =  84
# (2, 8, 9)  constraints =  85
# (3, 4, 5)  constraints =  86
# (3, 4, 6)  constraints =  87
# (3, 4, 7)  constraints =  88
# (3, 4, 8)  constraints =  89
# (3, 4, 9)  constraints =  90
# (3, 5, 6)  constraints =  91
# (3, 5, 7)  constraints =  92
# (3, 5, 8)  constraints =  93
# (3, 5, 9)  constraints =  94
# (3, 6, 7)  constraints =  95
# (3, 6, 8)  constraints =  96
# (3, 6, 9)  constraints =  97
# (3, 7, 8)  constraints =  98
# (3, 7, 9)  constraints =  99
# (3, 8, 9)  constraints =  100
# (4, 5, 6)  constraints =  101
# (4, 5, 7)  constraints =  102
# (4, 5, 8)  constraints =  103
# (4, 5, 9)  constraints =  104
# (4, 6, 7)  constraints =  105
# (4, 6, 8)  constraints =  106
# (4, 6, 9)  constraints =  107
# (4, 7, 8)  constraints =  108
# (4, 7, 9)  constraints =  109
# (4, 8, 9)  constraints =  110
# (5, 6, 7)  constraints =  111
# (5, 6, 8)  constraints =  112
# (5, 6, 9)  constraints =  113
# (5, 7, 8)  constraints =  114
# (5, 7, 9)  constraints =  115
# (5, 8, 9)  constraints =  116
# (6, 7, 8)  constraints =  117
# (6, 7, 9)  constraints =  118
# (6, 8, 9)  constraints =  119
# (7, 8, 9)  constraints =  120
# (0, 1, 2, 3)  constraints =  121
# (0, 1, 2, 4)  constraints =  122
# (0, 1, 2, 5)  constraints =  123
# (0, 1, 2, 6)  constraints =  124
# (0, 1, 2, 7)  constraints =  125
# (0, 1, 2, 8)  constraints =  126
# (0, 1, 2, 9)  constraints =  127
# (0, 1, 3, 4)  constraints =  128
# (0, 1, 3, 5)  constraints =  129
# (0, 1, 3, 6)  constraints =  130
# (0, 1, 3, 7)  constraints =  131
# (0, 1, 3, 8)  constraints =  132
# (0, 1, 3, 9)  constraints =  133
# (0, 1, 4, 5)  constraints =  134
# (0, 1, 4, 6)  constraints =  135
# (0, 1, 4, 7)  constraints =  136
# (0, 1, 4, 8)  constraints =  137
# (0, 1, 4, 9)  constraints =  138
# (0, 1, 5, 6)  constraints =  139
# (0, 1, 5, 7)  constraints =  140
# (0, 1, 5, 8)  constraints =  141
# (0, 1, 5, 9)  constraints =  142
# (0, 1, 6, 7)  constraints =  143
# (0, 1, 6, 8)  constraints =  144
# (0, 1, 6, 9)  constraints =  145
# (0, 1, 7, 8)  constraints =  146
# (0, 1, 7, 9)  constraints =  147
# (0, 1, 8, 9)  constraints =  148
# (0, 2, 3, 4)  constraints =  149
# (0, 2, 3, 5)  constraints =  150
# (0, 2, 3, 6)  constraints =  151
# (0, 2, 3, 7)  constraints =  152
# (0, 2, 3, 8)  constraints =  153
# (0, 2, 3, 9)  constraints =  154
# (0, 2, 4, 5)  constraints =  155
# (0, 2, 4, 6)  constraints =  156
# (0, 2, 4, 7)  constraints =  157
# (0, 2, 4, 8)  constraints =  158
# (0, 2, 4, 9)  constraints =  159
# (0, 2, 5, 6)  constraints =  160
# (0, 2, 5, 7)  constraints =  161
# (0, 2, 5, 8)  constraints =  162
# (0, 2, 5, 9)  constraints =  163
# (0, 2, 6, 7)  constraints =  164
# (0, 2, 6, 8)  constraints =  165
# (0, 2, 6, 9)  constraints =  166
# (0, 2, 7, 8)  constraints =  167
# (0, 2, 7, 9)  constraints =  168
# (0, 2, 8, 9)  constraints =  169
# (0, 3, 4, 5)  constraints =  170
# (0, 3, 4, 6)  constraints =  171
# (0, 3, 4, 7)  constraints =  172
# (0, 3, 4, 8)  constraints =  173
# (0, 3, 4, 9)  constraints =  174
# (0, 3, 5, 6)  constraints =  175
# (0, 3, 5, 7)  constraints =  176
# (0, 3, 5, 8)  constraints =  177
# (0, 3, 5, 9)  constraints =  178
# (0, 3, 6, 7)  constraints =  179
# (0, 3, 6, 8)  constraints =  180
# (0, 3, 6, 9)  constraints =  181
# (0, 3, 7, 8)  constraints =  182
# (0, 3, 7, 9)  constraints =  183
# (0, 3, 8, 9)  constraints =  184
# (0, 4, 5, 6)  constraints =  185
# (0, 4, 5, 7)  constraints =  186
# (0, 4, 5, 8)  constraints =  187
# (0, 4, 5, 9)  constraints =  188
# (0, 4, 6, 7)  constraints =  189
# (0, 4, 6, 8)  constraints =  190
# (0, 4, 6, 9)  constraints =  191
# (0, 4, 7, 8)  constraints =  192
# (0, 4, 7, 9)  constraints =  193
# (0, 4, 8, 9)  constraints =  194
# (0, 5, 6, 7)  constraints =  195
# (0, 5, 6, 8)  constraints =  196
# (0, 5, 6, 9)  constraints =  197
# (0, 5, 7, 8)  constraints =  198
# (0, 5, 7, 9)  constraints =  199
# (0, 5, 8, 9)  constraints =  200
# (0, 6, 7, 8)  constraints =  201
# (0, 6, 7, 9)  constraints =  202
# (0, 6, 8, 9)  constraints =  203
# (0, 7, 8, 9)  constraints =  204
# (1, 2, 3, 4)  constraints =  205
# (1, 2, 3, 5)  constraints =  206
# (1, 2, 3, 6)  constraints =  207
# (1, 2, 3, 7)  constraints =  208
# (1, 2, 3, 8)  constraints =  209
# (1, 2, 3, 9)  constraints =  210
# (1, 2, 4, 5)  constraints =  211
# (1, 2, 4, 6)  constraints =  212
# (1, 2, 4, 7)  constraints =  213
# (1, 2, 4, 8)  constraints =  214
# (1, 2, 4, 9)  constraints =  215
# (1, 2, 5, 6)  constraints =  216
# (1, 2, 5, 7)  constraints =  217
# (1, 2, 5, 8)  constraints =  218
# (1, 2, 5, 9)  constraints =  219
# (1, 2, 6, 7)  constraints =  220
# (1, 2, 6, 8)  constraints =  221
# (1, 2, 6, 9)  constraints =  222
# (1, 2, 7, 8)  constraints =  223
# (1, 2, 7, 9)  constraints =  224
# (1, 2, 8, 9)  constraints =  225
# (1, 3, 4, 5)  constraints =  226
# (1, 3, 4, 6)  constraints =  227
# (1, 3, 4, 7)  constraints =  228
# (1, 3, 4, 8)  constraints =  229
# (1, 3, 4, 9)  constraints =  230
# (1, 3, 5, 6)  constraints =  231
# (1, 3, 5, 7)  constraints =  232
# (1, 3, 5, 8)  constraints =  233
# (1, 3, 5, 9)  constraints =  234
# (1, 3, 6, 7)  constraints =  235
# (1, 3, 6, 8)  constraints =  236
# (1, 3, 6, 9)  constraints =  237
# (1, 3, 7, 8)  constraints =  238
# (1, 3, 7, 9)  constraints =  239
# (1, 3, 8, 9)  constraints =  240
# (1, 4, 5, 6)  constraints =  241
# (1, 4, 5, 7)  constraints =  242
# (1, 4, 5, 8)  constraints =  243
# (1, 4, 5, 9)  constraints =  244
# (1, 4, 6, 7)  constraints =  245
# (1, 4, 6, 8)  constraints =  246
# (1, 4, 6, 9)  constraints =  247
# (1, 4, 7, 8)  constraints =  248
# (1, 4, 7, 9)  constraints =  249
# (1, 4, 8, 9)  constraints =  250
# (1, 5, 6, 7)  constraints =  251
# (1, 5, 6, 8)  constraints =  252
# (1, 5, 6, 9)  constraints =  253
# (1, 5, 7, 8)  constraints =  254
# (1, 5, 7, 9)  constraints =  255
# (1, 5, 8, 9)  constraints =  256
# (1, 6, 7, 8)  constraints =  257
# (1, 6, 7, 9)  constraints =  258
# (1, 6, 8, 9)  constraints =  259
# (1, 7, 8, 9)  constraints =  260
# (2, 3, 4, 5)  constraints =  261
# (2, 3, 4, 6)  constraints =  262
# (2, 3, 4, 7)  constraints =  263
# (2, 3, 4, 8)  constraints =  264
# (2, 3, 4, 9)  constraints =  265
# (2, 3, 5, 6)  constraints =  266
# (2, 3, 5, 7)  constraints =  267
# (2, 3, 5, 8)  constraints =  268
# (2, 3, 5, 9)  constraints =  269
# (2, 3, 6, 7)  constraints =  270
# (2, 3, 6, 8)  constraints =  271
# (2, 3, 6, 9)  constraints =  272
# (2, 3, 7, 8)  constraints =  273
# (2, 3, 7, 9)  constraints =  274
# (2, 3, 8, 9)  constraints =  275
# (2, 4, 5, 6)  constraints =  276
# (2, 4, 5, 7)  constraints =  277
# (2, 4, 5, 8)  constraints =  278
# (2, 4, 5, 9)  constraints =  279
# (2, 4, 6, 7)  constraints =  280
# (2, 4, 6, 8)  constraints =  281
# (2, 4, 6, 9)  constraints =  282
# (2, 4, 7, 8)  constraints =  283
# (2, 4, 7, 9)  constraints =  284
# (2, 4, 8, 9)  constraints =  285
# (2, 5, 6, 7)  constraints =  286
# (2, 5, 6, 8)  constraints =  287
# (2, 5, 6, 9)  constraints =  288
# (2, 5, 7, 8)  constraints =  289
# (2, 5, 7, 9)  constraints =  290
# (2, 5, 8, 9)  constraints =  291
# (2, 6, 7, 8)  constraints =  292
# (2, 6, 7, 9)  constraints =  293
# (2, 6, 8, 9)  constraints =  294
# (2, 7, 8, 9)  constraints =  295
# (3, 4, 5, 6)  constraints =  296
# (3, 4, 5, 7)  constraints =  297
# (3, 4, 5, 8)  constraints =  298
# (3, 4, 5, 9)  constraints =  299
# (3, 4, 6, 7)  constraints =  300
# (3, 4, 6, 8)  constraints =  301
# (3, 4, 6, 9)  constraints =  302
# (3, 4, 7, 8)  constraints =  303
# (3, 4, 7, 9)  constraints =  304
# (3, 4, 8, 9)  constraints =  305
# (3, 5, 6, 7)  constraints =  306
# (3, 5, 6, 8)  constraints =  307
# (3, 5, 6, 9)  constraints =  308
# (3, 5, 7, 8)  constraints =  309
# (3, 5, 7, 9)  constraints =  310
# (3, 5, 8, 9)  constraints =  311
# (3, 6, 7, 8)  constraints =  312
# (3, 6, 7, 9)  constraints =  313
# (3, 6, 8, 9)  constraints =  314
# (3, 7, 8, 9)  constraints =  315
# (4, 5, 6, 7)  constraints =  316
# (4, 5, 6, 8)  constraints =  317
# (4, 5, 6, 9)  constraints =  318
# (4, 5, 7, 8)  constraints =  319
# (4, 5, 7, 9)  constraints =  320
# (4, 5, 8, 9)  constraints =  321
# (4, 6, 7, 8)  constraints =  322
# (4, 6, 7, 9)  constraints =  323
# (4, 6, 8, 9)  constraints =  324
# (4, 7, 8, 9)  constraints =  325
# (5, 6, 7, 8)  constraints =  326
# (5, 6, 7, 9)  constraints =  327
# (5, 6, 8, 9)  constraints =  328
# (5, 7, 8, 9)  constraints =  329
# (6, 7, 8, 9)  constraints =  330
# (0, 1, 2, 3, 4)  constraints =  331
# (0, 1, 2, 3, 5)  constraints =  332
# (0, 1, 2, 3, 6)  constraints =  333
# (0, 1, 2, 3, 7)  constraints =  334
# (0, 1, 2, 3, 8)  constraints =  335
# (0, 1, 2, 3, 9)  constraints =  336
# (0, 1, 2, 4, 5)  constraints =  337
# (0, 1, 2, 4, 6)  constraints =  338
# (0, 1, 2, 4, 7)  constraints =  339
# (0, 1, 2, 4, 8)  constraints =  340
# (0, 1, 2, 4, 9)  constraints =  341
# (0, 1, 2, 5, 6)  constraints =  342
# (0, 1, 2, 5, 7)  constraints =  343
# (0, 1, 2, 5, 8)  constraints =  344
# (0, 1, 2, 5, 9)  constraints =  345
# (0, 1, 2, 6, 7)  constraints =  346
# (0, 1, 2, 6, 8)  constraints =  347
# (0, 1, 2, 6, 9)  constraints =  348
# (0, 1, 2, 7, 8)  constraints =  349
# (0, 1, 2, 7, 9)  constraints =  350
# (0, 1, 2, 8, 9)  constraints =  351
# (0, 1, 3, 4, 5)  constraints =  352
# (0, 1, 3, 4, 6)  constraints =  353
# (0, 1, 3, 4, 7)  constraints =  354
# (0, 1, 3, 4, 8)  constraints =  355
# (0, 1, 3, 4, 9)  constraints =  356
# (0, 1, 3, 5, 6)  constraints =  357
# (0, 1, 3, 5, 7)  constraints =  358
# (0, 1, 3, 5, 8)  constraints =  359
# (0, 1, 3, 5, 9)  constraints =  360
# (0, 1, 3, 6, 7)  constraints =  361
# (0, 1, 3, 6, 8)  constraints =  362
# (0, 1, 3, 6, 9)  constraints =  363
# (0, 1, 3, 7, 8)  constraints =  364
# (0, 1, 3, 7, 9)  constraints =  365
# (0, 1, 3, 8, 9)  constraints =  366
# (0, 1, 4, 5, 6)  constraints =  367
# (0, 1, 4, 5, 7)  constraints =  368
# (0, 1, 4, 5, 8)  constraints =  369
# (0, 1, 4, 5, 9)  constraints =  370
# (0, 1, 4, 6, 7)  constraints =  371
# (0, 1, 4, 6, 8)  constraints =  372
# (0, 1, 4, 6, 9)  constraints =  373
# (0, 1, 4, 7, 8)  constraints =  374
# (0, 1, 4, 7, 9)  constraints =  375
# (0, 1, 4, 8, 9)  constraints =  376
# (0, 1, 5, 6, 7)  constraints =  377
# (0, 1, 5, 6, 8)  constraints =  378
# (0, 1, 5, 6, 9)  constraints =  379
# (0, 1, 5, 7, 8)  constraints =  380
# (0, 1, 5, 7, 9)  constraints =  381
# (0, 1, 5, 8, 9)  constraints =  382
# (0, 1, 6, 7, 8)  constraints =  383
# (0, 1, 6, 7, 9)  constraints =  384
# (0, 1, 6, 8, 9)  constraints =  385
# (0, 1, 7, 8, 9)  constraints =  386
# (0, 2, 3, 4, 5)  constraints =  387
# (0, 2, 3, 4, 6)  constraints =  388
# (0, 2, 3, 4, 7)  constraints =  389
# (0, 2, 3, 4, 8)  constraints =  390
# (0, 2, 3, 4, 9)  constraints =  391
# (0, 2, 3, 5, 6)  constraints =  392
# (0, 2, 3, 5, 7)  constraints =  393
# (0, 2, 3, 5, 8)  constraints =  394
# (0, 2, 3, 5, 9)  constraints =  395
# (0, 2, 3, 6, 7)  constraints =  396
# (0, 2, 3, 6, 8)  constraints =  397
# (0, 2, 3, 6, 9)  constraints =  398
# (0, 2, 3, 7, 8)  constraints =  399
# (0, 2, 3, 7, 9)  constraints =  400
# (0, 2, 3, 8, 9)  constraints =  401
# (0, 2, 4, 5, 6)  constraints =  402
# (0, 2, 4, 5, 7)  constraints =  403
# (0, 2, 4, 5, 8)  constraints =  404
# (0, 2, 4, 5, 9)  constraints =  405
# (0, 2, 4, 6, 7)  constraints =  406
# (0, 2, 4, 6, 8)  constraints =  407
# (0, 2, 4, 6, 9)  constraints =  408
# (0, 2, 4, 7, 8)  constraints =  409
# (0, 2, 4, 7, 9)  constraints =  410
# (0, 2, 4, 8, 9)  constraints =  411
# (0, 2, 5, 6, 7)  constraints =  412
# (0, 2, 5, 6, 8)  constraints =  413
# (0, 2, 5, 6, 9)  constraints =  414
# (0, 2, 5, 7, 8)  constraints =  415
# (0, 2, 5, 7, 9)  constraints =  416
# (0, 2, 5, 8, 9)  constraints =  417
# (0, 2, 6, 7, 8)  constraints =  418
# (0, 2, 6, 7, 9)  constraints =  419
# (0, 2, 6, 8, 9)  constraints =  420
# (0, 2, 7, 8, 9)  constraints =  421
# (0, 3, 4, 5, 6)  constraints =  422
# (0, 3, 4, 5, 7)  constraints =  423
# (0, 3, 4, 5, 8)  constraints =  424
# (0, 3, 4, 5, 9)  constraints =  425
# (0, 3, 4, 6, 7)  constraints =  426
# (0, 3, 4, 6, 8)  constraints =  427
# (0, 3, 4, 6, 9)  constraints =  428
# (0, 3, 4, 7, 8)  constraints =  429
# (0, 3, 4, 7, 9)  constraints =  430
# (0, 3, 4, 8, 9)  constraints =  431
# (0, 3, 5, 6, 7)  constraints =  432
# (0, 3, 5, 6, 8)  constraints =  433
# (0, 3, 5, 6, 9)  constraints =  434
# (0, 3, 5, 7, 8)  constraints =  435
# (0, 3, 5, 7, 9)  constraints =  436
# (0, 3, 5, 8, 9)  constraints =  437
# (0, 3, 6, 7, 8)  constraints =  438
# (0, 3, 6, 7, 9)  constraints =  439
# (0, 3, 6, 8, 9)  constraints =  440
# (0, 3, 7, 8, 9)  constraints =  441
# (0, 4, 5, 6, 7)  constraints =  442
# (0, 4, 5, 6, 8)  constraints =  443
# (0, 4, 5, 6, 9)  constraints =  444
# (0, 4, 5, 7, 8)  constraints =  445
# (0, 4, 5, 7, 9)  constraints =  446
# (0, 4, 5, 8, 9)  constraints =  447
# (0, 4, 6, 7, 8)  constraints =  448
# (0, 4, 6, 7, 9)  constraints =  449
# (0, 4, 6, 8, 9)  constraints =  450
# (0, 4, 7, 8, 9)  constraints =  451
# (0, 5, 6, 7, 8)  constraints =  452
# (0, 5, 6, 7, 9)  constraints =  453
# (0, 5, 6, 8, 9)  constraints =  454
# (0, 5, 7, 8, 9)  constraints =  455
# (0, 6, 7, 8, 9)  constraints =  456
# (1, 2, 3, 4, 5)  constraints =  457
# (1, 2, 3, 4, 6)  constraints =  458
# (1, 2, 3, 4, 7)  constraints =  459
# (1, 2, 3, 4, 8)  constraints =  460
# (1, 2, 3, 4, 9)  constraints =  461
# (1, 2, 3, 5, 6)  constraints =  462
# (1, 2, 3, 5, 7)  constraints =  463
# (1, 2, 3, 5, 8)  constraints =  464
# (1, 2, 3, 5, 9)  constraints =  465
# (1, 2, 3, 6, 7)  constraints =  466
# (1, 2, 3, 6, 8)  constraints =  467
# (1, 2, 3, 6, 9)  constraints =  468
# (1, 2, 3, 7, 8)  constraints =  469
# (1, 2, 3, 7, 9)  constraints =  470
# (1, 2, 3, 8, 9)  constraints =  471
# (1, 2, 4, 5, 6)  constraints =  472
# (1, 2, 4, 5, 7)  constraints =  473
# (1, 2, 4, 5, 8)  constraints =  474
# (1, 2, 4, 5, 9)  constraints =  475
# (1, 2, 4, 6, 7)  constraints =  476
# (1, 2, 4, 6, 8)  constraints =  477
# (1, 2, 4, 6, 9)  constraints =  478
# (1, 2, 4, 7, 8)  constraints =  479
# (1, 2, 4, 7, 9)  constraints =  480
# (1, 2, 4, 8, 9)  constraints =  481
# (1, 2, 5, 6, 7)  constraints =  482
# (1, 2, 5, 6, 8)  constraints =  483
# (1, 2, 5, 6, 9)  constraints =  484
# (1, 2, 5, 7, 8)  constraints =  485
# (1, 2, 5, 7, 9)  constraints =  486
# (1, 2, 5, 8, 9)  constraints =  487
# (1, 2, 6, 7, 8)  constraints =  488
# (1, 2, 6, 7, 9)  constraints =  489
# (1, 2, 6, 8, 9)  constraints =  490
# (1, 2, 7, 8, 9)  constraints =  491
# (1, 3, 4, 5, 6)  constraints =  492
# (1, 3, 4, 5, 7)  constraints =  493
# (1, 3, 4, 5, 8)  constraints =  494
# (1, 3, 4, 5, 9)  constraints =  495
# (1, 3, 4, 6, 7)  constraints =  496
# (1, 3, 4, 6, 8)  constraints =  497
# (1, 3, 4, 6, 9)  constraints =  498
# (1, 3, 4, 7, 8)  constraints =  499
# (1, 3, 4, 7, 9)  constraints =  500
# (1, 3, 4, 8, 9)  constraints =  501
# (1, 3, 5, 6, 7)  constraints =  502
# (1, 3, 5, 6, 8)  constraints =  503
# (1, 3, 5, 6, 9)  constraints =  504
# (1, 3, 5, 7, 8)  constraints =  505
# (1, 3, 5, 7, 9)  constraints =  506
# (1, 3, 5, 8, 9)  constraints =  507
# (1, 3, 6, 7, 8)  constraints =  508
# (1, 3, 6, 7, 9)  constraints =  509
# (1, 3, 6, 8, 9)  constraints =  510
# (1, 3, 7, 8, 9)  constraints =  511
# (1, 4, 5, 6, 7)  constraints =  512
# (1, 4, 5, 6, 8)  constraints =  513
# (1, 4, 5, 6, 9)  constraints =  514
# (1, 4, 5, 7, 8)  constraints =  515
# (1, 4, 5, 7, 9)  constraints =  516
# (1, 4, 5, 8, 9)  constraints =  517
# (1, 4, 6, 7, 8)  constraints =  518
# (1, 4, 6, 7, 9)  constraints =  519
# (1, 4, 6, 8, 9)  constraints =  520
# (1, 4, 7, 8, 9)  constraints =  521
# (1, 5, 6, 7, 8)  constraints =  522
# (1, 5, 6, 7, 9)  constraints =  523
# (1, 5, 6, 8, 9)  constraints =  524
# (1, 5, 7, 8, 9)  constraints =  525
# (1, 6, 7, 8, 9)  constraints =  526
# (2, 3, 4, 5, 6)  constraints =  527
# (2, 3, 4, 5, 7)  constraints =  528
# (2, 3, 4, 5, 8)  constraints =  529
# (2, 3, 4, 5, 9)  constraints =  530
# (2, 3, 4, 6, 7)  constraints =  531
# (2, 3, 4, 6, 8)  constraints =  532
# (2, 3, 4, 6, 9)  constraints =  533
# (2, 3, 4, 7, 8)  constraints =  534
# (2, 3, 4, 7, 9)  constraints =  535
# (2, 3, 4, 8, 9)  constraints =  536
# (2, 3, 5, 6, 7)  constraints =  537
# (2, 3, 5, 6, 8)  constraints =  538
# (2, 3, 5, 6, 9)  constraints =  539
# (2, 3, 5, 7, 8)  constraints =  540
# (2, 3, 5, 7, 9)  constraints =  541
# (2, 3, 5, 8, 9)  constraints =  542
# (2, 3, 6, 7, 8)  constraints =  543
# (2, 3, 6, 7, 9)  constraints =  544
# (2, 3, 6, 8, 9)  constraints =  545
# (2, 3, 7, 8, 9)  constraints =  546
# (2, 4, 5, 6, 7)  constraints =  547
# (2, 4, 5, 6, 8)  constraints =  548
# (2, 4, 5, 6, 9)  constraints =  549
# (2, 4, 5, 7, 8)  constraints =  550
# (2, 4, 5, 7, 9)  constraints =  551
# (2, 4, 5, 8, 9)  constraints =  552
# (2, 4, 6, 7, 8)  constraints =  553
# (2, 4, 6, 7, 9)  constraints =  554
# (2, 4, 6, 8, 9)  constraints =  555
# (2, 4, 7, 8, 9)  constraints =  556
# (2, 5, 6, 7, 8)  constraints =  557
# (2, 5, 6, 7, 9)  constraints =  558
# (2, 5, 6, 8, 9)  constraints =  559
# (2, 5, 7, 8, 9)  constraints =  560
# (2, 6, 7, 8, 9)  constraints =  561
# (3, 4, 5, 6, 7)  constraints =  562
# (3, 4, 5, 6, 8)  constraints =  563
# (3, 4, 5, 6, 9)  constraints =  564
# (3, 4, 5, 7, 8)  constraints =  565
# (3, 4, 5, 7, 9)  constraints =  566
# (3, 4, 5, 8, 9)  constraints =  567
# (3, 4, 6, 7, 8)  constraints =  568
# (3, 4, 6, 7, 9)  constraints =  569
# (3, 4, 6, 8, 9)  constraints =  570
# (3, 4, 7, 8, 9)  constraints =  571
# (3, 5, 6, 7, 8)  constraints =  572
# (3, 5, 6, 7, 9)  constraints =  573
# (3, 5, 6, 8, 9)  constraints =  574
# (3, 5, 7, 8, 9)  constraints =  575
# (3, 6, 7, 8, 9)  constraints =  576
# (4, 5, 6, 7, 8)  constraints =  577
# (4, 5, 6, 7, 9)  constraints =  578
# (4, 5, 6, 8, 9)  constraints =  579
# (4, 5, 7, 8, 9)  constraints =  580
# (4, 6, 7, 8, 9)  constraints =  581
# (5, 6, 7, 8, 9)  constraints =  582
# (0, 1, 2, 3, 4, 5)  constraints =  583
# (0, 1, 2, 3, 4, 6)  constraints =  584
# (0, 1, 2, 3, 4, 7)  constraints =  585
# (0, 1, 2, 3, 4, 8)  constraints =  586
# (0, 1, 2, 3, 4, 9)  constraints =  587
# (0, 1, 2, 3, 5, 6)  constraints =  588
# (0, 1, 2, 3, 5, 7)  constraints =  589
# (0, 1, 2, 3, 5, 8)  constraints =  590
# (0, 1, 2, 3, 5, 9)  constraints =  591
# (0, 1, 2, 3, 6, 7)  constraints =  592
# (0, 1, 2, 3, 6, 8)  constraints =  593
# (0, 1, 2, 3, 6, 9)  constraints =  594
# (0, 1, 2, 3, 7, 8)  constraints =  595
# (0, 1, 2, 3, 7, 9)  constraints =  596
# (0, 1, 2, 3, 8, 9)  constraints =  597
# (0, 1, 2, 4, 5, 6)  constraints =  598
# (0, 1, 2, 4, 5, 7)  constraints =  599
# (0, 1, 2, 4, 5, 8)  constraints =  600
# (0, 1, 2, 4, 5, 9)  constraints =  601
# (0, 1, 2, 4, 6, 7)  constraints =  602
# (0, 1, 2, 4, 6, 8)  constraints =  603
# (0, 1, 2, 4, 6, 9)  constraints =  604
# (0, 1, 2, 4, 7, 8)  constraints =  605
# (0, 1, 2, 4, 7, 9)  constraints =  606
# (0, 1, 2, 4, 8, 9)  constraints =  607
# (0, 1, 2, 5, 6, 7)  constraints =  608
# (0, 1, 2, 5, 6, 8)  constraints =  609
# (0, 1, 2, 5, 6, 9)  constraints =  610
# (0, 1, 2, 5, 7, 8)  constraints =  611
# (0, 1, 2, 5, 7, 9)  constraints =  612
# (0, 1, 2, 5, 8, 9)  constraints =  613
# (0, 1, 2, 6, 7, 8)  constraints =  614
# (0, 1, 2, 6, 7, 9)  constraints =  615
# (0, 1, 2, 6, 8, 9)  constraints =  616
# (0, 1, 2, 7, 8, 9)  constraints =  617
# (0, 1, 3, 4, 5, 6)  constraints =  618
# (0, 1, 3, 4, 5, 7)  constraints =  619
# (0, 1, 3, 4, 5, 8)  constraints =  620
# (0, 1, 3, 4, 5, 9)  constraints =  621
# (0, 1, 3, 4, 6, 7)  constraints =  622
# (0, 1, 3, 4, 6, 8)  constraints =  623
# (0, 1, 3, 4, 6, 9)  constraints =  624
# (0, 1, 3, 4, 7, 8)  constraints =  625
# (0, 1, 3, 4, 7, 9)  constraints =  626
# (0, 1, 3, 4, 8, 9)  constraints =  627
# (0, 1, 3, 5, 6, 7)  constraints =  628
# (0, 1, 3, 5, 6, 8)  constraints =  629
# (0, 1, 3, 5, 6, 9)  constraints =  630
# (0, 1, 3, 5, 7, 8)  constraints =  631
# (0, 1, 3, 5, 7, 9)  constraints =  632
# (0, 1, 3, 5, 8, 9)  constraints =  633
# (0, 1, 3, 6, 7, 8)  constraints =  634
# (0, 1, 3, 6, 7, 9)  constraints =  635
# (0, 1, 3, 6, 8, 9)  constraints =  636
# (0, 1, 3, 7, 8, 9)  constraints =  637
# (0, 1, 4, 5, 6, 7)  constraints =  638
# (0, 1, 4, 5, 6, 8)  constraints =  639
# (0, 1, 4, 5, 6, 9)  constraints =  640
# (0, 1, 4, 5, 7, 8)  constraints =  641
# (0, 1, 4, 5, 7, 9)  constraints =  642
# (0, 1, 4, 5, 8, 9)  constraints =  643
# (0, 1, 4, 6, 7, 8)  constraints =  644
# (0, 1, 4, 6, 7, 9)  constraints =  645
# (0, 1, 4, 6, 8, 9)  constraints =  646
# (0, 1, 4, 7, 8, 9)  constraints =  647
# (0, 1, 5, 6, 7, 8)  constraints =  648
# (0, 1, 5, 6, 7, 9)  constraints =  649
# (0, 1, 5, 6, 8, 9)  constraints =  650
# (0, 1, 5, 7, 8, 9)  constraints =  651
# (0, 1, 6, 7, 8, 9)  constraints =  652
# (0, 2, 3, 4, 5, 6)  constraints =  653
# (0, 2, 3, 4, 5, 7)  constraints =  654
# (0, 2, 3, 4, 5, 8)  constraints =  655
# (0, 2, 3, 4, 5, 9)  constraints =  656
# (0, 2, 3, 4, 6, 7)  constraints =  657
# (0, 2, 3, 4, 6, 8)  constraints =  658
# (0, 2, 3, 4, 6, 9)  constraints =  659
# (0, 2, 3, 4, 7, 8)  constraints =  660
# (0, 2, 3, 4, 7, 9)  constraints =  661
# (0, 2, 3, 4, 8, 9)  constraints =  662
# (0, 2, 3, 5, 6, 7)  constraints =  663
# (0, 2, 3, 5, 6, 8)  constraints =  664
# (0, 2, 3, 5, 6, 9)  constraints =  665
# (0, 2, 3, 5, 7, 8)  constraints =  666
# (0, 2, 3, 5, 7, 9)  constraints =  667
# (0, 2, 3, 5, 8, 9)  constraints =  668
# (0, 2, 3, 6, 7, 8)  constraints =  669
# (0, 2, 3, 6, 7, 9)  constraints =  670
# (0, 2, 3, 6, 8, 9)  constraints =  671
# (0, 2, 3, 7, 8, 9)  constraints =  672
# (0, 2, 4, 5, 6, 7)  constraints =  673
# (0, 2, 4, 5, 6, 8)  constraints =  674
# (0, 2, 4, 5, 6, 9)  constraints =  675
# (0, 2, 4, 5, 7, 8)  constraints =  676
# (0, 2, 4, 5, 7, 9)  constraints =  677
# (0, 2, 4, 5, 8, 9)  constraints =  678
# (0, 2, 4, 6, 7, 8)  constraints =  679
# (0, 2, 4, 6, 7, 9)  constraints =  680
# (0, 2, 4, 6, 8, 9)  constraints =  681
# (0, 2, 4, 7, 8, 9)  constraints =  682
# (0, 2, 5, 6, 7, 8)  constraints =  683
# (0, 2, 5, 6, 7, 9)  constraints =  684
# (0, 2, 5, 6, 8, 9)  constraints =  685
# (0, 2, 5, 7, 8, 9)  constraints =  686
# (0, 2, 6, 7, 8, 9)  constraints =  687
# (0, 3, 4, 5, 6, 7)  constraints =  688
# (0, 3, 4, 5, 6, 8)  constraints =  689
# (0, 3, 4, 5, 6, 9)  constraints =  690
# (0, 3, 4, 5, 7, 8)  constraints =  691
# (0, 3, 4, 5, 7, 9)  constraints =  692
# (0, 3, 4, 5, 8, 9)  constraints =  693
# (0, 3, 4, 6, 7, 8)  constraints =  694
# (0, 3, 4, 6, 7, 9)  constraints =  695
# (0, 3, 4, 6, 8, 9)  constraints =  696
# (0, 3, 4, 7, 8, 9)  constraints =  697
# (0, 3, 5, 6, 7, 8)  constraints =  698
# (0, 3, 5, 6, 7, 9)  constraints =  699
# (0, 3, 5, 6, 8, 9)  constraints =  700
# (0, 3, 5, 7, 8, 9)  constraints =  701
# (0, 3, 6, 7, 8, 9)  constraints =  702
# (0, 4, 5, 6, 7, 8)  constraints =  703
# (0, 4, 5, 6, 7, 9)  constraints =  704
# (0, 4, 5, 6, 8, 9)  constraints =  705
# (0, 4, 5, 7, 8, 9)  constraints =  706
# (0, 4, 6, 7, 8, 9)  constraints =  707
# (0, 5, 6, 7, 8, 9)  constraints =  708
# (1, 2, 3, 4, 5, 6)  constraints =  709
# (1, 2, 3, 4, 5, 7)  constraints =  710
# (1, 2, 3, 4, 5, 8)  constraints =  711
# (1, 2, 3, 4, 5, 9)  constraints =  712
# (1, 2, 3, 4, 6, 7)  constraints =  713
# (1, 2, 3, 4, 6, 8)  constraints =  714
# (1, 2, 3, 4, 6, 9)  constraints =  715
# (1, 2, 3, 4, 7, 8)  constraints =  716
# (1, 2, 3, 4, 7, 9)  constraints =  717
# (1, 2, 3, 4, 8, 9)  constraints =  718
# (1, 2, 3, 5, 6, 7)  constraints =  719
# (1, 2, 3, 5, 6, 8)  constraints =  720
# (1, 2, 3, 5, 6, 9)  constraints =  721
# (1, 2, 3, 5, 7, 8)  constraints =  722
# (1, 2, 3, 5, 7, 9)  constraints =  723
# (1, 2, 3, 5, 8, 9)  constraints =  724
# (1, 2, 3, 6, 7, 8)  constraints =  725
# (1, 2, 3, 6, 7, 9)  constraints =  726
# (1, 2, 3, 6, 8, 9)  constraints =  727
# (1, 2, 3, 7, 8, 9)  constraints =  728
# (1, 2, 4, 5, 6, 7)  constraints =  729
# (1, 2, 4, 5, 6, 8)  constraints =  730
# (1, 2, 4, 5, 6, 9)  constraints =  731
# (1, 2, 4, 5, 7, 8)  constraints =  732
# (1, 2, 4, 5, 7, 9)  constraints =  733
# (1, 2, 4, 5, 8, 9)  constraints =  734
# (1, 2, 4, 6, 7, 8)  constraints =  735
# (1, 2, 4, 6, 7, 9)  constraints =  736
# (1, 2, 4, 6, 8, 9)  constraints =  737
# (1, 2, 4, 7, 8, 9)  constraints =  738
# (1, 2, 5, 6, 7, 8)  constraints =  739
# (1, 2, 5, 6, 7, 9)  constraints =  740
# (1, 2, 5, 6, 8, 9)  constraints =  741
# (1, 2, 5, 7, 8, 9)  constraints =  742
# (1, 2, 6, 7, 8, 9)  constraints =  743
# (1, 3, 4, 5, 6, 7)  constraints =  744
# (1, 3, 4, 5, 6, 8)  constraints =  745
# (1, 3, 4, 5, 6, 9)  constraints =  746
# (1, 3, 4, 5, 7, 8)  constraints =  747
# (1, 3, 4, 5, 7, 9)  constraints =  748
# (1, 3, 4, 5, 8, 9)  constraints =  749
# (1, 3, 4, 6, 7, 8)  constraints =  750
# (1, 3, 4, 6, 7, 9)  constraints =  751
# (1, 3, 4, 6, 8, 9)  constraints =  752
# (1, 3, 4, 7, 8, 9)  constraints =  753
# (1, 3, 5, 6, 7, 8)  constraints =  754
# (1, 3, 5, 6, 7, 9)  constraints =  755
# (1, 3, 5, 6, 8, 9)  constraints =  756
# (1, 3, 5, 7, 8, 9)  constraints =  757
# (1, 3, 6, 7, 8, 9)  constraints =  758
# (1, 4, 5, 6, 7, 8)  constraints =  759
# (1, 4, 5, 6, 7, 9)  constraints =  760
# (1, 4, 5, 6, 8, 9)  constraints =  761
# (1, 4, 5, 7, 8, 9)  constraints =  762
# (1, 4, 6, 7, 8, 9)  constraints =  763
# (1, 5, 6, 7, 8, 9)  constraints =  764
# (2, 3, 4, 5, 6, 7)  constraints =  765
# (2, 3, 4, 5, 6, 8)  constraints =  766
# (2, 3, 4, 5, 6, 9)  constraints =  767
# (2, 3, 4, 5, 7, 8)  constraints =  768
# (2, 3, 4, 5, 7, 9)  constraints =  769
# (2, 3, 4, 5, 8, 9)  constraints =  770
# (2, 3, 4, 6, 7, 8)  constraints =  771
# (2, 3, 4, 6, 7, 9)  constraints =  772
# (2, 3, 4, 6, 8, 9)  constraints =  773
# (2, 3, 4, 7, 8, 9)  constraints =  774
# (2, 3, 5, 6, 7, 8)  constraints =  775
# (2, 3, 5, 6, 7, 9)  constraints =  776
# (2, 3, 5, 6, 8, 9)  constraints =  777
# (2, 3, 5, 7, 8, 9)  constraints =  778
# (2, 3, 6, 7, 8, 9)  constraints =  779
# (2, 4, 5, 6, 7, 8)  constraints =  780
# (2, 4, 5, 6, 7, 9)  constraints =  781
# (2, 4, 5, 6, 8, 9)  constraints =  782
# (2, 4, 5, 7, 8, 9)  constraints =  783
# (2, 4, 6, 7, 8, 9)  constraints =  784
# (2, 5, 6, 7, 8, 9)  constraints =  785
# (3, 4, 5, 6, 7, 8)  constraints =  786
# (3, 4, 5, 6, 7, 9)  constraints =  787
# (3, 4, 5, 6, 8, 9)  constraints =  788
# (3, 4, 5, 7, 8, 9)  constraints =  789
# (3, 4, 6, 7, 8, 9)  constraints =  790
# (3, 5, 6, 7, 8, 9)  constraints =  791
# (4, 5, 6, 7, 8, 9)  constraints =  792
# (0, 1, 2, 3, 4, 5, 6)  constraints =  793
# (0, 1, 2, 3, 4, 5, 7)  constraints =  794
# (0, 1, 2, 3, 4, 5, 8)  constraints =  795
# (0, 1, 2, 3, 4, 5, 9)  constraints =  796
# (0, 1, 2, 3, 4, 6, 7)  constraints =  797
# (0, 1, 2, 3, 4, 6, 8)  constraints =  798
# (0, 1, 2, 3, 4, 6, 9)  constraints =  799
# (0, 1, 2, 3, 4, 7, 8)  constraints =  800
# (0, 1, 2, 3, 4, 7, 9)  constraints =  801
# (0, 1, 2, 3, 4, 8, 9)  constraints =  802
# (0, 1, 2, 3, 5, 6, 7)  constraints =  803
# (0, 1, 2, 3, 5, 6, 8)  constraints =  804
# (0, 1, 2, 3, 5, 6, 9)  constraints =  805
# (0, 1, 2, 3, 5, 7, 8)  constraints =  806
# (0, 1, 2, 3, 5, 7, 9)  constraints =  807
# (0, 1, 2, 3, 5, 8, 9)  constraints =  808
# (0, 1, 2, 3, 6, 7, 8)  constraints =  809
# (0, 1, 2, 3, 6, 7, 9)  constraints =  810
# (0, 1, 2, 3, 6, 8, 9)  constraints =  811
# (0, 1, 2, 3, 7, 8, 9)  constraints =  812
# (0, 1, 2, 4, 5, 6, 7)  constraints =  813
# (0, 1, 2, 4, 5, 6, 8)  constraints =  814
# (0, 1, 2, 4, 5, 6, 9)  constraints =  815
# (0, 1, 2, 4, 5, 7, 8)  constraints =  816
# (0, 1, 2, 4, 5, 7, 9)  constraints =  817
# (0, 1, 2, 4, 5, 8, 9)  constraints =  818
# (0, 1, 2, 4, 6, 7, 8)  constraints =  819
# (0, 1, 2, 4, 6, 7, 9)  constraints =  820
# (0, 1, 2, 4, 6, 8, 9)  constraints =  821
# (0, 1, 2, 4, 7, 8, 9)  constraints =  822
# (0, 1, 2, 5, 6, 7, 8)  constraints =  823
# (0, 1, 2, 5, 6, 7, 9)  constraints =  824
# (0, 1, 2, 5, 6, 8, 9)  constraints =  825
# (0, 1, 2, 5, 7, 8, 9)  constraints =  826
# (0, 1, 2, 6, 7, 8, 9)  constraints =  827
# (0, 1, 3, 4, 5, 6, 7)  constraints =  828
# (0, 1, 3, 4, 5, 6, 8)  constraints =  829
# (0, 1, 3, 4, 5, 6, 9)  constraints =  830
# (0, 1, 3, 4, 5, 7, 8)  constraints =  831
# (0, 1, 3, 4, 5, 7, 9)  constraints =  832
# (0, 1, 3, 4, 5, 8, 9)  constraints =  833
# (0, 1, 3, 4, 6, 7, 8)  constraints =  834
# (0, 1, 3, 4, 6, 7, 9)  constraints =  835
# (0, 1, 3, 4, 6, 8, 9)  constraints =  836
# (0, 1, 3, 4, 7, 8, 9)  constraints =  837
# (0, 1, 3, 5, 6, 7, 8)  constraints =  838
# (0, 1, 3, 5, 6, 7, 9)  constraints =  839
# (0, 1, 3, 5, 6, 8, 9)  constraints =  840
# (0, 1, 3, 5, 7, 8, 9)  constraints =  841
# (0, 1, 3, 6, 7, 8, 9)  constraints =  842
# (0, 1, 4, 5, 6, 7, 8)  constraints =  843
# (0, 1, 4, 5, 6, 7, 9)  constraints =  844
# (0, 1, 4, 5, 6, 8, 9)  constraints =  845
# (0, 1, 4, 5, 7, 8, 9)  constraints =  846
# (0, 1, 4, 6, 7, 8, 9)  constraints =  847
# (0, 1, 5, 6, 7, 8, 9)  constraints =  848
# (0, 2, 3, 4, 5, 6, 7)  constraints =  849
# (0, 2, 3, 4, 5, 6, 8)  constraints =  850
# (0, 2, 3, 4, 5, 6, 9)  constraints =  851
# (0, 2, 3, 4, 5, 7, 8)  constraints =  852
# (0, 2, 3, 4, 5, 7, 9)  constraints =  853
# (0, 2, 3, 4, 5, 8, 9)  constraints =  854
# (0, 2, 3, 4, 6, 7, 8)  constraints =  855
# (0, 2, 3, 4, 6, 7, 9)  constraints =  856
# (0, 2, 3, 4, 6, 8, 9)  constraints =  857
# (0, 2, 3, 4, 7, 8, 9)  constraints =  858
# (0, 2, 3, 5, 6, 7, 8)  constraints =  859
# (0, 2, 3, 5, 6, 7, 9)  constraints =  860
# (0, 2, 3, 5, 6, 8, 9)  constraints =  861
# (0, 2, 3, 5, 7, 8, 9)  constraints =  862
# (0, 2, 3, 6, 7, 8, 9)  constraints =  863
# (0, 2, 4, 5, 6, 7, 8)  constraints =  864
# (0, 2, 4, 5, 6, 7, 9)  constraints =  865
# (0, 2, 4, 5, 6, 8, 9)  constraints =  866
# (0, 2, 4, 5, 7, 8, 9)  constraints =  867
# (0, 2, 4, 6, 7, 8, 9)  constraints =  868
# (0, 2, 5, 6, 7, 8, 9)  constraints =  869
# (0, 3, 4, 5, 6, 7, 8)  constraints =  870
# (0, 3, 4, 5, 6, 7, 9)  constraints =  871
# (0, 3, 4, 5, 6, 8, 9)  constraints =  872
# (0, 3, 4, 5, 7, 8, 9)  constraints =  873
# (0, 3, 4, 6, 7, 8, 9)  constraints =  874
# (0, 3, 5, 6, 7, 8, 9)  constraints =  875
# (0, 4, 5, 6, 7, 8, 9)  constraints =  876
# (1, 2, 3, 4, 5, 6, 7)  constraints =  877
# (1, 2, 3, 4, 5, 6, 8)  constraints =  878
# (1, 2, 3, 4, 5, 6, 9)  constraints =  879
# (1, 2, 3, 4, 5, 7, 8)  constraints =  880
# (1, 2, 3, 4, 5, 7, 9)  constraints =  881
# (1, 2, 3, 4, 5, 8, 9)  constraints =  882
# (1, 2, 3, 4, 6, 7, 8)  constraints =  883
# (1, 2, 3, 4, 6, 7, 9)  constraints =  884
# (1, 2, 3, 4, 6, 8, 9)  constraints =  885
# (1, 2, 3, 4, 7, 8, 9)  constraints =  886
# (1, 2, 3, 5, 6, 7, 8)  constraints =  887
# (1, 2, 3, 5, 6, 7, 9)  constraints =  888
# (1, 2, 3, 5, 6, 8, 9)  constraints =  889
# (1, 2, 3, 5, 7, 8, 9)  constraints =  890
# (1, 2, 3, 6, 7, 8, 9)  constraints =  891
# (1, 2, 4, 5, 6, 7, 8)  constraints =  892
# (1, 2, 4, 5, 6, 7, 9)  constraints =  893
# (1, 2, 4, 5, 6, 8, 9)  constraints =  894
# (1, 2, 4, 5, 7, 8, 9)  constraints =  895
# (1, 2, 4, 6, 7, 8, 9)  constraints =  896
# (1, 2, 5, 6, 7, 8, 9)  constraints =  897
# (1, 3, 4, 5, 6, 7, 8)  constraints =  898
# (1, 3, 4, 5, 6, 7, 9)  constraints =  899
# (1, 3, 4, 5, 6, 8, 9)  constraints =  900
# (1, 3, 4, 5, 7, 8, 9)  constraints =  901
# (1, 3, 4, 6, 7, 8, 9)  constraints =  902
# (1, 3, 5, 6, 7, 8, 9)  constraints =  903
# (1, 4, 5, 6, 7, 8, 9)  constraints =  904
# (2, 3, 4, 5, 6, 7, 8)  constraints =  905
# (2, 3, 4, 5, 6, 7, 9)  constraints =  906
# (2, 3, 4, 5, 6, 8, 9)  constraints =  907
# (2, 3, 4, 5, 7, 8, 9)  constraints =  908
# (2, 3, 4, 6, 7, 8, 9)  constraints =  909
# (2, 3, 5, 6, 7, 8, 9)  constraints =  910
# (2, 4, 5, 6, 7, 8, 9)  constraints =  911
# (3, 4, 5, 6, 7, 8, 9)  constraints =  912
# (0, 1, 2, 3, 4, 5, 6, 7)  constraints =  913
# (0, 1, 2, 3, 4, 5, 6, 8)  constraints =  914
# (0, 1, 2, 3, 4, 5, 6, 9)  constraints =  915
# (0, 1, 2, 3, 4, 5, 7, 8)  constraints =  916
# (0, 1, 2, 3, 4, 5, 7, 9)  constraints =  917
# (0, 1, 2, 3, 4, 5, 8, 9)  constraints =  918
# (0, 1, 2, 3, 4, 6, 7, 8)  constraints =  919
# (0, 1, 2, 3, 4, 6, 7, 9)  constraints =  920
# (0, 1, 2, 3, 4, 6, 8, 9)  constraints =  921
# (0, 1, 2, 3, 4, 7, 8, 9)  constraints =  922
# (0, 1, 2, 3, 5, 6, 7, 8)  constraints =  923
# (0, 1, 2, 3, 5, 6, 7, 9)  constraints =  924
# (0, 1, 2, 3, 5, 6, 8, 9)  constraints =  925
# (0, 1, 2, 3, 5, 7, 8, 9)  constraints =  926
# (0, 1, 2, 3, 6, 7, 8, 9)  constraints =  927
# (0, 1, 2, 4, 5, 6, 7, 8)  constraints =  928
# (0, 1, 2, 4, 5, 6, 7, 9)  constraints =  929
# (0, 1, 2, 4, 5, 6, 8, 9)  constraints =  930
# (0, 1, 2, 4, 5, 7, 8, 9)  constraints =  931
# (0, 1, 2, 4, 6, 7, 8, 9)  constraints =  932
# (0, 1, 2, 5, 6, 7, 8, 9)  constraints =  933
# (0, 1, 3, 4, 5, 6, 7, 8)  constraints =  934
# (0, 1, 3, 4, 5, 6, 7, 9)  constraints =  935
# (0, 1, 3, 4, 5, 6, 8, 9)  constraints =  936
# (0, 1, 3, 4, 5, 7, 8, 9)  constraints =  937
# (0, 1, 3, 4, 6, 7, 8, 9)  constraints =  938
# (0, 1, 3, 5, 6, 7, 8, 9)  constraints =  939
# (0, 1, 4, 5, 6, 7, 8, 9)  constraints =  940
# (0, 2, 3, 4, 5, 6, 7, 8)  constraints =  941
# (0, 2, 3, 4, 5, 6, 7, 9)  constraints =  942
# (0, 2, 3, 4, 5, 6, 8, 9)  constraints =  943
# (0, 2, 3, 4, 5, 7, 8, 9)  constraints =  944
# (0, 2, 3, 4, 6, 7, 8, 9)  constraints =  945
# (0, 2, 3, 5, 6, 7, 8, 9)  constraints =  946
# (0, 2, 4, 5, 6, 7, 8, 9)  constraints =  947
# (0, 3, 4, 5, 6, 7, 8, 9)  constraints =  948
# (1, 2, 3, 4, 5, 6, 7, 8)  constraints =  949
# (1, 2, 3, 4, 5, 6, 7, 9)  constraints =  950
# (1, 2, 3, 4, 5, 6, 8, 9)  constraints =  951
# (1, 2, 3, 4, 5, 7, 8, 9)  constraints =  952
# (1, 2, 3, 4, 6, 7, 8, 9)  constraints =  953
# (1, 2, 3, 5, 6, 7, 8, 9)  constraints =  954
# (1, 2, 4, 5, 6, 7, 8, 9)  constraints =  955
# (1, 3, 4, 5, 6, 7, 8, 9)  constraints =  956
# (2, 3, 4, 5, 6, 7, 8, 9)  constraints =  957
# (0, 1, 2, 3, 4, 5, 6, 7, 8)  constraints =  958
# (0, 1, 2, 3, 4, 5, 6, 7, 9)  constraints =  959
# (0, 1, 2, 3, 4, 5, 6, 8, 9)  constraints =  960
# (0, 1, 2, 3, 4, 5, 7, 8, 9)  constraints =  961
# (0, 1, 2, 3, 4, 6, 7, 8, 9)  constraints =  962
# (0, 1, 2, 3, 5, 6, 7, 8, 9)  constraints =  963
# (0, 1, 2, 4, 5, 6, 7, 8, 9)  constraints =  964
# (0, 1, 3, 4, 5, 6, 7, 8, 9)  constraints =  965
# (0, 2, 3, 4, 5, 6, 7, 8, 9)  constraints =  966
# (1, 2, 3, 4, 5, 6, 7, 8, 9)  constraints =  967
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 977 rows, 45 columns and 11520 nonzeros
# Model fingerprint: 0x29d811f6
# Variable types: 0 continuous, 45 integer (45 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 8e+00]
# Found heuristic solution: objective 584.1217158
# Presolve time: 0.00s
# Presolved: 977 rows, 45 columns, 11520 nonzeros
# Variable types: 0 continuous, 45 integer (45 binary)
#
# Root relaxation: objective 3.027546e+02, 16 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     302.7546404  302.75464  0.00%     -    0s
#
# Explored 1 nodes (16 simplex iterations) in 0.02 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 302.755 584.122
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.027546403604e+02, best bound 3.027546403604e+02, gap 0.0000%
#
# Optimal tour: [3, 0, 7, 8, 2, 1, 6, 5, 4, 9]
# Optimal cost: 302.7546403604325

# %% [markdown]
# ## Number of constraints
#
# \begin{align}
# \Huge
# \approx 2^n& \\
# \Huge
# &\Huge 2^{10} = 1024
# \end{align}

# %%
# Full model
m = gp.Model()

# Create variables
x = tupledict()
for i, j in dist.keys():
    x[i, j] = m.addVar(vtype=GRB.BINARY, name=f'x[{i},{j}]')
    x[j, i] = x[i, j]  # Edges both directions are the same 

# Add degree-2 constraints

m.addConstrs(x.sum(i, '*') == 2 for i in range(n))

# subtour constraints

#m.addConstr(gp.quicksum(x[i, j] for i, j in combinations(subtour, 2)) <= len(subtour)-1)


objective = gp.quicksum(dist[i, j] * x[i, j] for i, j in dist.keys())
m.setObjective(objective, GRB.MINIMIZE)
m.setParam("OutputFlag", 1)

# Optimize model

m.optimize()

vals = m.getAttr('X', x)
edges = gp.tuplelist((i, j) for i, j in vals.keys() if vals[i, j] > 0.5)
tour = build_tour_from_edges(edges)

print('')
print(f'Optimal tour: {str(tour)}')
print(f'Optimal cost: {m.ObjVal}')
print('')

figure_TSP(tour)
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 10 rows, 45 columns and 90 nonzeros
# Model fingerprint: 0xe143fde1
# Variable types: 0 continuous, 45 integer (45 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Found heuristic solution: objective 566.5292943
# Presolve time: 0.00s
# Presolved: 10 rows, 45 columns, 90 nonzeros
# Variable types: 0 continuous, 45 integer (45 binary)
#
# Root relaxation: objective 2.951918e+02, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0     295.1918192  295.19182  0.00%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 295.192 566.529
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.951918192103e+02, best bound 2.951918192103e+02, gap 0.0000%
#
# Optimal tour: [2, 0, 7, 8]
# Optimal cost: 295.19181921030383

# %% [markdown]
# ### Part 2: Write the subtour identification function

# %%
# Callback - use lazy constraints to eliminate sub-tours

def subtourelim(model, where):
    # if we find an integer solution
    if where == GRB.Callback.MIPSOL:
        # then read out the values
        vals = model.cbGetSolution(model._vars)
        print("Calling Callback")
        # find the shortest cycle in the solution
        tour = subtour(vals)
        print("Detected subtour = ", tour)
        # if the cycle is not the whole set, then add a cut to remove it
        if len(tour) < n:
            # add subtour elimination constr. for every pair of cities in tour
            model.cbLazy(gp.quicksum(model._vars[i, j] for i, j in combinations(tour, 2)) <= len(tour)-1)

# %%
example_vals = {(1, 0): 1.0, (0, 1): 1.0, (2, 0): 0.0, (0, 2): 0.0, (2, 1): 0.0, (1, 2): 0.0, (3, 0): 0.0, (0, 3): 0.0, (3, 1): 0.0, (1, 3): 0.0, (3, 2): 0.0, (2, 3): 0.0, (4, 0): 0.0, (0, 4): 0.0, (4, 1): 0.0, (1, 4): 0.0, (4, 2): 0.0, (2, 4): 0.0, (4, 3): 0.0, (3, 4): 0.0, (5, 0): 0.0, (0, 5): 0.0, (5, 1): 0.0, (1, 5): 0.0, (5, 2): 0.0, (2, 5): 0.0, (5, 3): 1.0, (3, 5): 1.0, (5, 4): 0.0, (4, 5): 0.0, (6, 0): 0.0, (0, 6): 0.0, (6, 1): 0.0, (1, 6): 0.0, (6, 2): 1.0, (2, 6): 1.0, (6, 3): 0.0, (3, 6): 0.0, (6, 4): 1.0, (4, 6): 1.0, (6, 5): 0.0, (5, 6): 0.0, (7, 0): 0.0, (0, 7): 0.0, (7, 1): 0.0, (1, 7): 0.0, (7, 2): 1.0, (2, 7): 1.0, (7, 3): 0.0, (3, 7): 0.0, (7, 4): 1.0, (4, 7): 1.0, (7, 5): 0.0, (5, 7): 0.0, (7, 6): 0.0, (6, 7): 0.0, (8, 0): 1.0, (0, 8): 1.0, (8, 1): 1.0, (1, 8): 1.0, (8, 2): 0.0, (2, 8): 0.0, (8, 3): 0.0, (3, 8): 0.0, (8, 4): 0.0, (4, 8): 0.0, (8, 5): 0.0, (5, 8): 0.0, (8, 6): 0.0, (6, 8): 0.0, (8, 7): 0.0, (7, 8): 0.0, (9, 0): 0.0, (0, 9): 0.0, (9, 1): 0.0, (1, 9): 0.0, (9, 2): 0.0, (2, 9): 0.0, (9, 3): 1.0, (3, 9): 1.0, (9, 4): 0.0, (4, 9): 0.0, (9, 5): 1.0, (5, 9): 1.0, (9, 6): 0.0, (6, 9): 0.0, (9, 7): 0.0, (7, 9): 0.0, (9, 8): 0.0, (8, 9): 0.0}

# %%
# Given a tuplelist of edges, find the shortest subtour
# input: dictionary of solution values for all edges
# output: List of nodes that build shortest cycle (ex. [0, 2, 4, 1])
def subtour(vals):
    # make a list of edges selected in the solution
    edges = gp.tuplelist((i, j) for i, j in vals.keys() if vals[i, j] > 0.5) # numercial safety
    unvisited = list(range(n))
    cycle = range(n+1)  # largest cycle has length n + 1
    while len(unvisited) >= 1: # while there are unvisited nodes
        thiscycle = [] # initialize empty cycle
        neighbors = unvisited # initialize "neighbours" to be everyone
        while len(neighbors) >= 1: # while there are neighbours left
            current = neighbors[0] # take first neighbour in list
            thiscycle.append(current) # add neighbour to cycle
            unvisited.remove(current) # remove neighbour from unvisited nodes
            neighbors = [j for i, j in edges.select(current, '*') if j in unvisited] 
            
            # define neighbours to be the nodes for which there is an edge from current node
            
            # basically as soon as we finish walking along edges and there are suddendly no 
            
            # neighbours left, it means we already visited all neighbours ==> cycle
            
            # with the degree 2 constraint, cycles are the only possible structure
        
        if len(thiscycle) < len(cycle):
            cycle = thiscycle
    return cycle

# %%
subtour(example_vals)
# Out:
# [0, 1, 8]

# %% [markdown]
# ### Part 3: Code the model using lazy constraints

# %%
# Lazy constraints model
m = gp.Model()

# Create variables
x = tupledict()
for i, j in dist.keys():
    x[i, j] = m.addVar(vtype=GRB.BINARY, name=f'x[{i},{j}]')
    x[j, i] = x[i, j]  # edge in opposite direction

# Add degree-2 constraint
m.addConstrs(x.sum(i, '*') == 2 for i in range(n))


# set objective
objective = gp.quicksum(dist[i, j] * x[i, j] for i, j in dist.keys())
m.setObjective(objective, GRB.MINIMIZE)

# Optimize model
m._vars = x # store variables in model m._vars
m.Params.LazyConstraints = 1
m.optimize(subtourelim)

vals = m.getAttr('X', x)
edges = gp.tuplelist((i, j) for i, j in x.keys() if vals[i, j] > 0.5)
tour = build_tour_from_edges(edges)


print('')
print(f'Optimal tour: {str(tour)}')
print(f'Optimal cost: {m.ObjVal}')
print('')

figure_TSP(tour)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 10 rows, 45 columns and 90 nonzeros
# Model fingerprint: 0xe143fde1
# Variable types: 0 continuous, 45 integer (45 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Calling Callback
# Detected subtour =  [0, 1, 8]
# Presolve time: 0.00s
# Presolved: 10 rows, 45 columns, 90 nonzeros
# Variable types: 0 continuous, 45 integer (45 binary)
# Calling Callback
# Detected subtour =  [1, 5, 6]
# Calling Callback
# Detected subtour =  [0, 8, 1, 9]
#
# Root relaxation: objective 3.018755e+02, 15 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  301.87549    0    6          -  301.87549      -     -    0s
# Calling Callback
# Detected subtour =  [0, 7, 8, 2, 1, 6, 5, 4, 3, 9]
# H    0     0                     309.0937026  301.87549  2.34%     -    0s
# Calling Callback
# Detected subtour =  [0, 7, 8]
# Calling Callback
# Detected subtour =  [0, 3, 9, 4, 5, 6, 1, 2, 8, 7]
# H    0     0                     302.7546404  301.87549  0.29%     -    0s
#      0     0  301.87549    0    6  302.75464  301.87549  0.29%     -    0s
#
# Cutting planes:
#   Lazy constraints: 3
#
# Explored 1 nodes (15 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 302.755 309.094
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.027546403604e+02, best bound 3.027546403604e+02, gap 0.0000%
#
# User-callback calls 111, time in user-callback 0.00 sec
#
# Optimal tour: [3, 0, 7, 8, 2, 1, 6, 5, 4, 9]
# Optimal cost: 302.7546403604325

# %% [markdown]
# ## Exercise 2: Extension to VRP

# %% [markdown]
# \begin{align*}
#     Minimize & \sum_{i,j\in E}c_{i,j}x_{i,j}\\
#     \textit{s.t.}&
#     \sum_{i,j \in A | i < j } x_{i,j}=2 & \forall i \in V\setminus \{0\},\\
#     &\sum_{i,j \in A | i,j \in S }x_{i,j} \leq |S|-\left \lceil\frac{\sum_{i\in S}q_i}{Q} \right \rceil & \forall S\subseteq N, S \neq \emptyset,\\
#     &\nonumber x_{ij} \in \{0,1\} & \forall (i,j)\in A.
# \end{align*}

# %%
Depot = (50,50) # Depot coordinates
cities = [(Depot)] #coordinates of all customers
Depot_id = 0 # Depot idendifier
cities += [(17, 72), (97, 8), (32, 15), (63, 97), (57, 60), (83, 48), (100, 26), (12, 62), (3, 49), (55, 77), 
          (97, 98), (0, 89), (57, 34), (92, 29), (75, 13), (40, 3), (2, 3), (83, 69), (1, 48), (87, 27), 
          (54, 92), (3, 67), (28, 97), (56, 63), (70, 29), (44, 29), (86, 28), (97, 58), (37, 2), (53, 71), 
          (82, 12), (23, 80), (92, 37), (15, 95), (42, 92), (91, 64), (54, 64), (85, 24), (38, 36), (75, 63), 
          (64, 50), (75, 4), (61, 31), (95, 51), (53, 85), (22, 46), (70, 89), (99, 86), (94, 47), (11, 56)]

n = len(cities)

# Dictionary of Euclidean distance between each pair of points
dist = {(i, j): math.sqrt(sum((cities[i][k]-cities[j][k])**2 for k in range(2))) for i in range(n) for j in range(i)}

# Capacity of vehicle
Q = 20
print(n)
# Out:
# 51

# %%
# Graph the input
x = [el[1] for el in cities]
y = [el[0] for el in cities]
plt.scatter(x, y,color = 'r')
ax = plt.gca()
ax.plot(cities[Depot_id][1],cities[Depot_id][0], 's', color = 'black')
plt.show()

# %% [markdown]
# ## Giant tour representation of VRP
# The depot is 0. Each time we return to the depot we add a 0 to the list
#
# Example of giant tour = [0, 1, 2, 3, 4, 5, 0, 6, 7, 8, 0, 9, 10, 11, 12, 13, 14, 15, 0]

# %%
# Given a tuplelist of edges, build the full path of all vehicles, as one long path
def buildpath(vals):
    # first check if anything is connected to the depot at all
    unvisited = list(range(n)) 
    edges = gp.tuplelist((i, j) for i, j in vals.keys() if vals[i, j] > 0.5)
    neighbors = [j for i, j in edges.select(Depot_id, '*') if j in unvisited]
    path = []
    if len(neighbors) == 0: # if nothing is connected to the depot, return an empty list
        return path
    
    # if there are nodes connected to the depot:
    path.append(Depot_id) # add the depot to the path
    
    # build the long path
    while len(neighbors) >= 1:
        path.append(neighbors[-1])
        if neighbors[-1] != Depot_id:
            unvisited.remove(neighbors[-1])
        neighbors = [j for i, j in edges.select(path[-1], '*') if j in unvisited]
    return path

# %%
# plotting function for the solution

def figure_VRP(t):
    ax = plt.gca()
    ax.cla() # clear things for fresh plot

    # change default range so that new circles will work
    ax.set_xlim((-5, 105))
    ax.set_ylim((-5, 105))
    a = []
    b = []
    
    for i in t:
        #ax.plot(cities[i][1],cities[i][0], 'o',color = 'r')
        a = np.append(a, cities[i][1])
        b = np.append(b, cities[i][0])    
    a = np.append(a, cities[tour[0]][1])
    b = np.append(b, cities[tour[0]][0]) 
    ax.plot(a,b)
    for i in t:
        ax.plot(cities[i][1], cities[i][0], 'o',color = 'r')
        ax.text(cities[i][1], cities[i][0], str(i), color='black', fontsize=8)
    ax.plot(cities[Depot_id][1], cities[Depot_id][0], 's', color = 'black')

    plt.show()

# %%
# Adjusted callback function

def subtourelim_VRP(model, where):
    if where == GRB.Callback.MIPSOL:
        vals = model.cbGetSolution(model._vars)
        subtour = subtourVRP(vals) # returns a subset that violates the constraints. 
        
        model.cbLazy(gp.quicksum(model._vars[i, j] for i, j in combinations(subtour, 2))\
                     <= len(subtour)-math.ceil(len(subtour)/Q))

# %%
# Given a tuplelist of edges, find the shortest subtour
# input: dictionary of solution values for all edges
# output: List of nodes that build shortest cycle (ex. [0, 2, 4, 1])
def subtourVRP(vals):
    
    # make a list of edges selected in the solution
    edges = gp.tuplelist((i, j) for i, j in vals.keys() if vals[i, j] > 0.75) # numercial safety
    unvisited = list(range(n))
    cycle = list(range(n))  # largest cycle has length n
    
    return cycle

# %%
m = gp.Model()

# Create variables
x = tupledict()
for i, j in dist.keys():
    x[i, j] = m.addVar(vtype=GRB.BINARY, name=f'x[{i},{j}]')
    x[j, i] = x[i, j]  # make your life easier by not having to worry about indexing order


# Add degree-2 constraint
for i in range(n):
    if i != Depot_id:
        m.addConstr(sum(x[i,j] for j in range(n) if i!=j) == 2)
        

# set objective
objective = gp.quicksum(dist[i, j] * x[i, j] for i, j in dist.keys())
m.setObjective(objective, GRB.MINIMIZE)


# Optimize model
m._vars = x
m.Params.LazyConstraints = 1
m.optimize(subtourelim_VRP)

vals = m.getAttr('X', x)
edges = gp.tuplelist((i, j) for i, j in vals.keys() if vals[i, j] > 0.5 if i < j)
tour = buildpath(vals)

figure_VRP(tour)

print("number of cities (with depot): ",  n)
print("Cities ", cities)
print('')
print('Optimal tour: %s' % str(tour))
print('Optimal cost: %g' % m.ObjVal)
print('')
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i7-1165G7 @ 2.80GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 50 rows, 1275 columns and 2500 nonzeros
# Model fingerprint: 0x1de508e0
# Variable types: 0 continuous, 1275 integer (1275 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 2e+00]
# Presolve time: 0.01s
# Presolved: 50 rows, 1275 columns, 2500 nonzeros
# Variable types: 0 continuous, 1275 integer (1275 binary)
#
# Root relaxation: infeasible, 72 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 infeasible    0               - infeasible      -     -    0s
#
# Cutting planes:
#   Lazy constraints: 1
#
# Explored 1 nodes (72 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -
#
# User-callback calls 104, time in user-callback 0.00 sec
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[24], line 26
#      23 m.Params.LazyConstraints = 1
#      24 m.optimize(subtourelim_VRP)
# ---> 26 vals = m.getAttr('X', x)
#      27 edges = gp.tuplelist((i, j) for i, j in vals.keys() if vals[i, j] > 0.5 if i < j)
#      28 tour = buildpath(vals)
#
# File src\\gurobipy\\model.pxi:1912, in gurobipy.Model.getAttr()
#
# File src\\gurobipy\\attrutil.pxi:151, in gurobipy._gettypedattrlist()
#
# GurobiError: Unable to retrieve attribute 'X'
